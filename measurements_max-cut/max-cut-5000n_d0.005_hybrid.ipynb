# %% [markdown]
# # Max-Cut Sample - Hybrid

# %%
import matplotlib.pyplot as plt
import networkx as nx
import dwave_networkx as dnx
import dimod

# %% [markdown]
# ### Helper Functions

# %%
def draw_graph(G,cut,pos):
    colors = [ 'g' if n in cut else 'r' for n in G.nodes() ]
    nx.draw(G,with_labels=False,alpha=0.6,node_size=50,node_color=colors,pos=pos)
    
def cut_size(G,cut):
    edges = 0
    for c in cut:
        for n in G.neighbors(c):
            if n not in cut:
                edges += 1
    return edges

# %% [markdown]
# ## Problem as Graph

# %%
# fixed graph
#G = nx.Graph()
#G.add_nodes_from([0,1,2,3,4])
#G.add_edges_from([(0,1),(1,2),(2,3),(3,0),(0,4),(2,4),(3,4),(1,4)])

# loaded sample graph
G = nx.read_edgelist('../sample_graphs/5000-nodes-sample.dat',nodetype=int)

#n = 4
#p = 0.3
#H = nx.gnp_random_graph(n, p)
pos = nx.spring_layout(G)

#nx.draw(G,with_labels=True,alpha=0.6,node_size=300,pos=pos)
draw_graph(G,{},pos)

# %%
print('Graph: ',len(G.nodes()), 'nodes, density: ',nx.density(G))
# Out:
# Graph:  5000 nodes, density:  0.00500748149629926

# %% [markdown]
# ## Exact Solver

# %%
exactsolver = dimod.ExactSolver()

# %%
#import time

#ts_start = time.time()
#cut = dnx.maximum_cut(G, exactsolver)
#ts_stop = time.time()
#print(cut)
#print('elapsed time of exact solver (s): ',round(ts_stop - ts_start,2))

# %%
#draw_graph(G,cut,pos)

# %%
#print('cut-size: ',cut_size(G,cut))

# %% [markdown]
# ## Hybrid Solver

# %%
from dwave.system import LeapHybridSampler

label = 'max-cut, n: ' + str(len(G.nodes())) + ', d: ' + str(round(nx.density(G),2)) + ' hybrid'

hybridsampler = LeapHybridSampler()
cut = dnx.maximum_cut(G, hybridsampler,label=label)

# %%
cut
# Out:
# {1,
#  6,
#  7,
#  9,
#  13,
#  14,
#  15,
#  16,
#  19,
#  20,
#  21,
#  22,
#  23,
#  27,
#  29,
#  30,
#  31,
#  36,
#  39,
#  40,
#  44,
#  47,
#  49,
#  50,
#  51,
#  52,
#  57,
#  58,
#  60,
#  61,
#  65,
#  67,
#  70,
#  71,
#  73,
#  74,
#  76,
#  81,
#  83,
#  84,
#  85,
#  86,
#  87,
#  89,
#  94,
#  97,
#  98,
#  99,
#  100,
#  103,
#  107,
#  110,
#  111,
#  113,
#  114,
#  118,
#  119,
#  120,
#  122,
#  127,
#  128,
#  129,
#  130,
#  132,
#  133,
#  136,
#  139,
#  142,
#  143,
#  144,
#  147,
#  148,
#  149,
#  150,
#  151,
#  156,
#  157,
#  160,
#  161,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  174,
#  177,
#  179,
#  183,
#  184,
#  189,
#  190,
#  192,
#  194,
#  195,
#  197,
#  199,
#  200,
#  205,
#  206,
#  207,
#  210,
#  211,
#  214,
#  215,
#  217,
#  218,
#  220,
#  221,
#  222,
#  224,
#  226,
#  230,
#  231,
#  232,
#  234,
#  235,
#  238,
#  239,
#  241,
#  242,
#  244,
#  245,
#  247,
#  248,
#  250,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  262,
#  263,
#  265,
#  266,
#  267,
#  268,
#  270,
#  271,
#  272,
#  276,
#  278,
#  280,
#  281,
#  282,
#  283,
#  284,
#  285,
#  286,
#  287,
#  289,
#  291,
#  292,
#  298,
#  299,
#  300,
#  301,
#  302,
#  304,
#  305,
#  309,
#  310,
#  312,
#  313,
#  317,
#  318,
#  323,
#  324,
#  332,
#  335,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  356,
#  357,
#  359,
#  360,
#  361,
#  363,
#  365,
#  367,
#  368,
#  369,
#  373,
#  378,
#  379,
#  383,
#  384,
#  386,
#  390,
#  391,
#  392,
#  394,
#  402,
#  403,
#  406,
#  408,
#  409,
#  411,
#  413,
#  414,
#  416,
#  417,
#  420,
#  423,
#  424,
#  425,
#  428,
#  430,
#  431,
#  435,
#  436,
#  437,
#  438,
#  439,
#  442,
#  448,
#  449,
#  450,
#  452,
#  454,
#  457,
#  458,
#  460,
#  464,
#  465,
#  466,
#  467,
#  472,
#  474,
#  475,
#  477,
#  478,
#  480,
#  481,
#  483,
#  487,
#  490,
#  492,
#  494,
#  495,
#  497,
#  499,
#  500,
#  501,
#  503,
#  506,
#  510,
#  511,
#  514,
#  515,
#  517,
#  519,
#  521,
#  525,
#  527,
#  531,
#  534,
#  535,
#  537,
#  539,
#  540,
#  541,
#  542,
#  544,
#  545,
#  547,
#  548,
#  549,
#  551,
#  553,
#  554,
#  555,
#  556,
#  559,
#  560,
#  562,
#  564,
#  567,
#  569,
#  571,
#  572,
#  574,
#  575,
#  576,
#  577,
#  582,
#  583,
#  584,
#  585,
#  586,
#  591,
#  592,
#  593,
#  595,
#  596,
#  599,
#  602,
#  603,
#  605,
#  606,
#  608,
#  609,
#  610,
#  611,
#  613,
#  618,
#  626,
#  627,
#  628,
#  630,
#  631,
#  634,
#  635,
#  636,
#  637,
#  638,
#  639,
#  642,
#  645,
#  649,
#  650,
#  651,
#  652,
#  653,
#  656,
#  657,
#  658,
#  659,
#  664,
#  666,
#  671,
#  675,
#  678,
#  679,
#  681,
#  685,
#  686,
#  688,
#  689,
#  691,
#  695,
#  696,
#  697,
#  698,
#  700,
#  701,
#  704,
#  708,
#  711,
#  714,
#  715,
#  716,
#  717,
#  720,
#  722,
#  725,
#  728,
#  730,
#  734,
#  735,
#  736,
#  737,
#  738,
#  739,
#  743,
#  744,
#  745,
#  749,
#  750,
#  751,
#  752,
#  753,
#  759,
#  763,
#  764,
#  765,
#  767,
#  768,
#  770,
#  777,
#  778,
#  781,
#  782,
#  783,
#  784,
#  786,
#  788,
#  790,
#  791,
#  793,
#  795,
#  796,
#  798,
#  799,
#  800,
#  801,
#  802,
#  807,
#  809,
#  810,
#  811,
#  812,
#  813,
#  815,
#  816,
#  819,
#  820,
#  821,
#  822,
#  823,
#  824,
#  826,
#  829,
#  830,
#  832,
#  834,
#  835,
#  837,
#  838,
#  839,
#  840,
#  841,
#  842,
#  843,
#  847,
#  848,
#  849,
#  850,
#  851,
#  856,
#  859,
#  862,
#  863,
#  864,
#  865,
#  868,
#  869,
#  870,
#  871,
#  872,
#  873,
#  878,
#  879,
#  881,
#  882,
#  884,
#  887,
#  888,
#  891,
#  894,
#  895,
#  901,
#  903,
#  905,
#  907,
#  911,
#  916,
#  918,
#  920,
#  921,
#  922,
#  923,
#  924,
#  930,
#  931,
#  935,
#  938,
#  940,
#  941,
#  942,
#  944,
#  945,
#  948,
#  955,
#  957,
#  959,
#  962,
#  967,
#  973,
#  974,
#  975,
#  979,
#  981,
#  983,
#  985,
#  987,
#  988,
#  990,
#  993,
#  994,
#  995,
#  996,
#  999,
#  1000,
#  1003,
#  1005,
#  1006,
#  1008,
#  1009,
#  1010,
#  1012,
#  1014,
#  1018,
#  1021,
#  1022,
#  1024,
#  1025,
#  1026,
#  1028,
#  1031,
#  1032,
#  1034,
#  1035,
#  1036,
#  1037,
#  1039,
#  1040,
#  1041,
#  1042,
#  1043,
#  1046,
#  1048,
#  1052,
#  1053,
#  1054,
#  1057,
#  1059,
#  1060,
#  1064,
#  1066,
#  1068,
#  1069,
#  1078,
#  1080,
#  1082,
#  1083,
#  1084,
#  1085,
#  1087,
#  1088,
#  1089,
#  1095,
#  1098,
#  1099,
#  1100,
#  1102,
#  1103,
#  1106,
#  1107,
#  1108,
#  1109,
#  1111,
#  1114,
#  1118,
#  1119,
#  1121,
#  1123,
#  1126,
#  1127,
#  1130,
#  1134,
#  1136,
#  1137,
#  1138,
#  1139,
#  1142,
#  1143,
#  1144,
#  1145,
#  1146,
#  1148,
#  1150,
#  1151,
#  1152,
#  1155,
#  1157,
#  1158,
#  1160,
#  1161,
#  1163,
#  1165,
#  1166,
#  1168,
#  1170,
#  1171,
#  1175,
#  1178,
#  1180,
#  1182,
#  1183,
#  1184,
#  1185,
#  1187,
#  1189,
#  1192,
#  1193,
#  1196,
#  1197,
#  1201,
#  1207,
#  1209,
#  1211,
#  1212,
#  1213,
#  1217,
#  1219,
#  1221,
#  1222,
#  1223,
#  1225,
#  1227,
#  1229,
#  1231,
#  1232,
#  1233,
#  1236,
#  1238,
#  1239,
#  1241,
#  1242,
#  1243,
#  1244,
#  1249,
#  1250,
#  1252,
#  1253,
#  1256,
#  1257,
#  1260,
#  1261,
#  1262,
#  1263,
#  1264,
#  1265,
#  1269,
#  1270,
#  1274,
#  1276,
#  1277,
#  1279,
#  1280,
#  1282,
#  1283,
#  1285,
#  1286,
#  1290,
#  1292,
#  1295,
#  1296,
#  1299,
#  1305,
#  1306,
#  1313,
#  1318,
#  1319,
#  1323,
#  1324,
#  1325,
#  1327,
#  1332,
#  1334,
#  1336,
#  1338,
#  1339,
#  1340,
#  1341,
#  1342,
#  1346,
#  1349,
#  1352,
#  1357,
#  1358,
#  1361,
#  1362,
#  1363,
#  1366,
#  1367,
#  1368,
#  1369,
#  1375,
#  1376,
#  1377,
#  1379,
#  1380,
#  1381,
#  1382,
#  1383,
#  1384,
#  1387,
#  1388,
#  1390,
#  1393,
#  1394,
#  1395,
#  1398,
#  1399,
#  1401,
#  1402,
#  1410,
#  1411,
#  1412,
#  1415,
#  1417,
#  1420,
#  1422,
#  1425,
#  1427,
#  1428,
#  1430,
#  1433,
#  1435,
#  1437,
#  1440,
#  1441,
#  1444,
#  1446,
#  1449,
#  1455,
#  1456,
#  1459,
#  1460,
#  1462,
#  1463,
#  1464,
#  1467,
#  1469,
#  1470,
#  1471,
#  1475,
#  1476,
#  1479,
#  1480,
#  1482,
#  1483,
#  1485,
#  1486,
#  1487,
#  1491,
#  1492,
#  1495,
#  1498,
#  1499,
#  1501,
#  1502,
#  1505,
#  1506,
#  1507,
#  1509,
#  1513,
#  1514,
#  1515,
#  1522,
#  1523,
#  1524,
#  1525,
#  1526,
#  1528,
#  1530,
#  1531,
#  1532,
#  1533,
#  1534,
#  1535,
#  1536,
#  1537,
#  1538,
#  1539,
#  1542,
#  1543,
#  1546,
#  1547,
#  1549,
#  1550,
#  1552,
#  1554,
#  1558,
#  1560,
#  1561,
#  1562,
#  1563,
#  1565,
#  1572,
#  1573,
#  1575,
#  1578,
#  1581,
#  1584,
#  1587,
#  1589,
#  1595,
#  1596,
#  1597,
#  1600,
#  1603,
#  1605,
#  1606,
#  1607,
#  1608,
#  1609,
#  1610,
#  1612,
#  1613,
#  1614,
#  1615,
#  1618,
#  1621,
#  1622,
#  1624,
#  1625,
#  1627,
#  1628,
#  1633,
#  1635,
#  1636,
#  1637,
#  1638,
#  1639,
#  1640,
#  1641,
#  1642,
#  1646,
#  1647,
#  1649,
#  1652,
#  1657,
#  1662,
#  1663,
#  1665,
#  1666,
#  1668,
#  1673,
#  1674,
#  1676,
#  1687,
#  1688,
#  1692,
#  1694,
#  1695,
#  1696,
#  1697,
#  1699,
#  1700,
#  1701,
#  1703,
#  1705,
#  1706,
#  1707,
#  1708,
#  1711,
#  1713,
#  1715,
#  1716,
#  1718,
#  1723,
#  1724,
#  1725,
#  1727,
#  1729,
#  1730,
#  1732,
#  1742,
#  1745,
#  1748,
#  1749,
#  1754,
#  1756,
#  1757,
#  1758,
#  1760,
#  1763,
#  1765,
#  1766,
#  1767,
#  1770,
#  1773,
#  1784,
#  1785,
#  1786,
#  1788,
#  1789,
#  1792,
#  1793,
#  1794,
#  1796,
#  1797,
#  1803,
#  1805,
#  1807,
#  1809,
#  1811,
#  1812,
#  1815,
#  1816,
#  1817,
#  1819,
#  1820,
#  1821,
#  1824,
#  1825,
#  1826,
#  1831,
#  1836,
#  1838,
#  1840,
#  1848,
#  1850,
#  1851,
#  1854,
#  1855,
#  1858,
#  1859,
#  1860,
#  1861,
#  1862,
#  1865,
#  1868,
#  1869,
#  1872,
#  1878,
#  1879,
#  1881,
#  1882,
#  1885,
#  1887,
#  1889,
#  1891,
#  1892,
#  1894,
#  1895,
#  1897,
#  1900,
#  1901,
#  1902,
#  1905,
#  1908,
#  1909,
#  1911,
#  1915,
#  1917,
#  1918,
#  1919,
#  1921,
#  1922,
#  1923,
#  1924,
#  1927,
#  1930,
#  1931,
#  1934,
#  1935,
#  1936,
#  1938,
#  1940,
#  1942,
#  1943,
#  1944,
#  1946,
#  1947,
#  1948,
#  1949,
#  1951,
#  1952,
#  1953,
#  1954,
#  1955,
#  1956,
#  1958,
#  1963,
#  1964,
#  1970,
#  1973,
#  1976,
#  1977,
#  1979,
#  1980,
#  1982,
#  1983,
#  1984,
#  1986,
#  1987,
#  1989,
#  1990,
#  1994,
#  1996,
#  1998,
#  1999,
#  2000,
#  ...}

# %%
draw_graph(G,cut,pos)

# %%
print('cut-size: ',cut_size(G,cut))
# Out:
# cut-size:  40685

# %%
len(list(G.neighbors(3455)))
# Out:
# 19
