# %% [markdown]
# # Max-Cut Sample - Hybrid

# %%
import matplotlib.pyplot as plt
import networkx as nx
import dwave_networkx as dnx
import dimod

# %% [markdown]
# ### Helper Functions

# %%
def draw_graph(G,cut,pos):
    colors = [ 'g' if n in cut else 'r' for n in G.nodes() ]
    nx.draw(G,with_labels=False,alpha=0.6,node_size=50,node_color=colors,pos=pos)
    
def cut_size(G,cut):
    edges = 0
    for c in cut:
        for n in G.neighbors(c):
            if n not in cut:
                edges += 1
    return edges

# %% [markdown]
# ## Problem as Graph

# %%
# fixed graph
#G = nx.Graph()
#G.add_nodes_from([0,1,2,3,4])
#G.add_edges_from([(0,1),(1,2),(2,3),(3,0),(0,4),(2,4),(3,4),(1,4)])

# loaded sample graph
G = nx.read_edgelist('../sample_graphs/1000-nodes-sample.dat',nodetype=int)

#n = 4
#p = 0.3
#H = nx.gnp_random_graph(n, p)
pos = nx.spring_layout(G)

#nx.draw(G,with_labels=True,alpha=0.6,node_size=300,pos=pos)
draw_graph(G,{},pos)

# %%
print('Graph: ',len(G.nodes()), 'nodes, density: ',nx.density(G))
# Out:
# Graph:  1000 nodes, density:  0.010016016016016016

# %% [markdown]
# ## Exact Solver

# %%
exactsolver = dimod.ExactSolver()

# %%
#import time

#ts_start = time.time()
#cut = dnx.maximum_cut(G, exactsolver)
#ts_stop = time.time()
#print(cut)
#print('elapsed time of exact solver (s): ',round(ts_stop - ts_start,2))

# %%
#draw_graph(G,cut,pos)

# %%
#print('cut-size: ',cut_size(G,cut))

# %% [markdown]
# ## Hybrid Solver

# %%
from dwave.system import LeapHybridSampler

label = 'max-cut, n: ' + str(len(G.nodes())) + ', d: ' + str(round(nx.density(G),2)) + ' hybrid'

hybridsampler = LeapHybridSampler()
cut = dnx.maximum_cut(G, hybridsampler,label=label)

# %%
cut
# Out:
# {0,
#  1,
#  4,
#  5,
#  9,
#  10,
#  11,
#  12,
#  13,
#  15,
#  16,
#  20,
#  22,
#  23,
#  24,
#  28,
#  32,
#  35,
#  37,
#  40,
#  41,
#  43,
#  45,
#  47,
#  50,
#  51,
#  52,
#  53,
#  55,
#  57,
#  58,
#  59,
#  61,
#  62,
#  66,
#  67,
#  68,
#  69,
#  70,
#  74,
#  76,
#  77,
#  79,
#  85,
#  86,
#  87,
#  88,
#  89,
#  90,
#  92,
#  94,
#  96,
#  100,
#  102,
#  103,
#  106,
#  107,
#  111,
#  112,
#  114,
#  116,
#  120,
#  125,
#  126,
#  127,
#  128,
#  132,
#  133,
#  134,
#  135,
#  137,
#  141,
#  146,
#  147,
#  150,
#  151,
#  152,
#  155,
#  159,
#  161,
#  163,
#  164,
#  165,
#  167,
#  168,
#  169,
#  172,
#  174,
#  176,
#  177,
#  178,
#  180,
#  181,
#  185,
#  189,
#  190,
#  191,
#  192,
#  193,
#  195,
#  198,
#  199,
#  200,
#  203,
#  207,
#  208,
#  210,
#  211,
#  213,
#  214,
#  216,
#  217,
#  218,
#  220,
#  223,
#  224,
#  225,
#  226,
#  229,
#  235,
#  238,
#  240,
#  242,
#  244,
#  245,
#  247,
#  248,
#  251,
#  255,
#  262,
#  263,
#  265,
#  266,
#  270,
#  271,
#  273,
#  274,
#  275,
#  277,
#  278,
#  279,
#  281,
#  283,
#  284,
#  285,
#  287,
#  289,
#  292,
#  295,
#  300,
#  304,
#  305,
#  307,
#  310,
#  312,
#  313,
#  315,
#  316,
#  317,
#  319,
#  322,
#  324,
#  325,
#  326,
#  327,
#  330,
#  332,
#  335,
#  337,
#  339,
#  340,
#  341,
#  342,
#  344,
#  346,
#  347,
#  349,
#  350,
#  351,
#  353,
#  357,
#  359,
#  360,
#  361,
#  366,
#  368,
#  369,
#  370,
#  372,
#  374,
#  377,
#  379,
#  380,
#  381,
#  387,
#  389,
#  390,
#  392,
#  393,
#  397,
#  398,
#  399,
#  400,
#  401,
#  402,
#  403,
#  405,
#  406,
#  408,
#  411,
#  412,
#  413,
#  415,
#  419,
#  420,
#  423,
#  428,
#  429,
#  435,
#  438,
#  439,
#  440,
#  442,
#  444,
#  447,
#  448,
#  449,
#  450,
#  453,
#  457,
#  461,
#  462,
#  463,
#  464,
#  465,
#  467,
#  470,
#  471,
#  477,
#  478,
#  480,
#  481,
#  482,
#  486,
#  491,
#  493,
#  494,
#  496,
#  499,
#  500,
#  501,
#  502,
#  506,
#  508,
#  509,
#  510,
#  511,
#  512,
#  518,
#  521,
#  522,
#  523,
#  529,
#  530,
#  531,
#  533,
#  534,
#  535,
#  536,
#  537,
#  539,
#  541,
#  543,
#  545,
#  546,
#  549,
#  551,
#  554,
#  555,
#  556,
#  559,
#  560,
#  562,
#  564,
#  566,
#  570,
#  571,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  584,
#  588,
#  589,
#  590,
#  591,
#  593,
#  595,
#  596,
#  597,
#  599,
#  600,
#  602,
#  605,
#  607,
#  611,
#  612,
#  613,
#  615,
#  616,
#  617,
#  618,
#  619,
#  621,
#  622,
#  623,
#  625,
#  627,
#  629,
#  631,
#  637,
#  638,
#  639,
#  640,
#  641,
#  647,
#  648,
#  653,
#  655,
#  657,
#  659,
#  660,
#  661,
#  664,
#  666,
#  667,
#  672,
#  673,
#  675,
#  678,
#  680,
#  681,
#  682,
#  683,
#  685,
#  686,
#  688,
#  691,
#  692,
#  693,
#  696,
#  697,
#  698,
#  699,
#  702,
#  705,
#  708,
#  709,
#  714,
#  715,
#  717,
#  719,
#  720,
#  722,
#  726,
#  727,
#  728,
#  733,
#  736,
#  740,
#  741,
#  743,
#  748,
#  749,
#  750,
#  751,
#  758,
#  760,
#  762,
#  763,
#  765,
#  766,
#  769,
#  772,
#  776,
#  777,
#  779,
#  781,
#  782,
#  786,
#  788,
#  790,
#  791,
#  792,
#  794,
#  799,
#  802,
#  804,
#  805,
#  807,
#  808,
#  810,
#  812,
#  814,
#  816,
#  817,
#  820,
#  821,
#  822,
#  824,
#  825,
#  826,
#  827,
#  830,
#  831,
#  833,
#  834,
#  835,
#  836,
#  838,
#  839,
#  841,
#  842,
#  844,
#  846,
#  848,
#  851,
#  854,
#  857,
#  859,
#  860,
#  862,
#  863,
#  864,
#  867,
#  869,
#  870,
#  871,
#  873,
#  874,
#  875,
#  876,
#  877,
#  878,
#  879,
#  880,
#  887,
#  891,
#  896,
#  898,
#  900,
#  903,
#  904,
#  906,
#  908,
#  909,
#  910,
#  911,
#  913,
#  914,
#  915,
#  919,
#  924,
#  928,
#  929,
#  930,
#  932,
#  938,
#  939,
#  940,
#  942,
#  943,
#  944,
#  945,
#  946,
#  947,
#  951,
#  954,
#  955,
#  956,
#  960,
#  962,
#  963,
#  964,
#  965,
#  966,
#  967,
#  968,
#  971,
#  972,
#  973,
#  976,
#  978,
#  979,
#  980,
#  985,
#  986,
#  989,
#  991,
#  992,
#  995,
#  996,
#  999}

# %%
draw_graph(G,cut,pos)

# %%
print('cut-size: ',cut_size(G,cut))
# Out:
# cut-size:  3660
