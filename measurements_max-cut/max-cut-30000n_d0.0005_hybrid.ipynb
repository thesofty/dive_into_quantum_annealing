# %% [markdown]
# # Max-Cut Sample - Hybrid

# %%
import matplotlib.pyplot as plt
import networkx as nx
import dwave_networkx as dnx
import dimod

# %% [markdown]
# ### Helper Functions

# %%
def draw_graph(G,cut,pos):
    colors = [ 'g' if n in cut else 'r' for n in G.nodes() ]
    nx.draw(G,with_labels=False,alpha=0.6,node_size=50,node_color=colors,pos=pos)
    
def cut_size(G,cut):
    edges = 0
    for c in cut:
        for n in G.neighbors(c):
            if n not in cut:
                edges += 1
    return edges

# %% [markdown]
# ## Problem as Graph

# %%
# fixed graph
#G = nx.Graph()
#G.add_nodes_from([0,1,2,3,4])
#G.add_edges_from([(0,1),(1,2),(2,3),(3,0),(0,4),(2,4),(3,4),(1,4)])

# loaded sample graph
G = nx.read_edgelist('../sample_graphs/30000-nodes-sample.dat',nodetype=int)

#n = 4
#p = 0.3
#H = nx.gnp_random_graph(n, p)
pos = nx.spring_layout(G)

#nx.draw(G,with_labels=True,alpha=0.6,node_size=300,pos=pos)
draw_graph(G,{},pos)

# %%
print('Graph: ',len(G.nodes()), 'nodes, density: ',nx.density(G))
# Out:
# Graph:  30000 nodes, density:  0.0004995788748513839

# %% [markdown]
# ## Exact Solver

# %%
exactsolver = dimod.ExactSolver()

# %%
#import time

#ts_start = time.time()
#cut = dnx.maximum_cut(G, exactsolver)
#ts_stop = time.time()
#print(cut)
#print('elapsed time of exact solver (s): ',round(ts_stop - ts_start,2))

# %%
#draw_graph(G,cut,pos)

# %%
#print('cut-size: ',cut_size(G,cut))

# %% [markdown]
# ## Hybrid Solver

# %%
from dwave.system import LeapHybridSampler

label = 'max-cut, n: ' + str(len(G.nodes())) + ', d: ' + str(round(nx.density(G),2)) + ' hybrid'

hybridsampler = LeapHybridSampler()
cut = dnx.maximum_cut(G, hybridsampler,label=label)

# %%
cut
# Out:
# {0,
#  2,
#  3,
#  6,
#  11,
#  13,
#  15,
#  16,
#  21,
#  22,
#  25,
#  27,
#  28,
#  29,
#  31,
#  34,
#  36,
#  40,
#  43,
#  48,
#  51,
#  53,
#  55,
#  56,
#  57,
#  58,
#  62,
#  63,
#  64,
#  65,
#  66,
#  67,
#  69,
#  71,
#  76,
#  77,
#  78,
#  80,
#  81,
#  82,
#  85,
#  87,
#  88,
#  89,
#  90,
#  93,
#  95,
#  96,
#  100,
#  102,
#  106,
#  107,
#  109,
#  111,
#  112,
#  113,
#  115,
#  120,
#  123,
#  125,
#  126,
#  128,
#  130,
#  132,
#  133,
#  135,
#  136,
#  137,
#  138,
#  139,
#  141,
#  142,
#  143,
#  146,
#  148,
#  150,
#  151,
#  152,
#  157,
#  159,
#  163,
#  164,
#  166,
#  167,
#  168,
#  169,
#  170,
#  171,
#  172,
#  173,
#  175,
#  178,
#  179,
#  181,
#  183,
#  186,
#  187,
#  190,
#  191,
#  193,
#  194,
#  197,
#  198,
#  200,
#  202,
#  203,
#  208,
#  209,
#  212,
#  213,
#  215,
#  216,
#  217,
#  219,
#  222,
#  224,
#  225,
#  226,
#  227,
#  228,
#  229,
#  230,
#  232,
#  233,
#  236,
#  237,
#  239,
#  243,
#  245,
#  250,
#  252,
#  255,
#  256,
#  259,
#  260,
#  262,
#  264,
#  265,
#  268,
#  270,
#  273,
#  274,
#  276,
#  277,
#  282,
#  286,
#  288,
#  290,
#  292,
#  293,
#  294,
#  295,
#  297,
#  298,
#  299,
#  301,
#  303,
#  308,
#  311,
#  312,
#  313,
#  315,
#  316,
#  318,
#  323,
#  326,
#  331,
#  332,
#  333,
#  334,
#  336,
#  338,
#  341,
#  343,
#  344,
#  345,
#  347,
#  354,
#  355,
#  357,
#  358,
#  359,
#  360,
#  364,
#  365,
#  366,
#  368,
#  369,
#  370,
#  372,
#  373,
#  375,
#  377,
#  378,
#  379,
#  382,
#  383,
#  386,
#  388,
#  396,
#  398,
#  401,
#  403,
#  404,
#  405,
#  406,
#  408,
#  410,
#  411,
#  412,
#  413,
#  424,
#  425,
#  426,
#  430,
#  431,
#  433,
#  435,
#  436,
#  438,
#  439,
#  440,
#  441,
#  443,
#  445,
#  448,
#  449,
#  450,
#  452,
#  456,
#  457,
#  458,
#  459,
#  461,
#  463,
#  464,
#  466,
#  467,
#  468,
#  470,
#  473,
#  474,
#  483,
#  485,
#  487,
#  488,
#  490,
#  491,
#  493,
#  495,
#  497,
#  498,
#  501,
#  502,
#  504,
#  506,
#  507,
#  509,
#  510,
#  514,
#  518,
#  522,
#  524,
#  527,
#  529,
#  533,
#  534,
#  536,
#  537,
#  539,
#  540,
#  542,
#  543,
#  546,
#  548,
#  549,
#  550,
#  552,
#  554,
#  561,
#  564,
#  565,
#  566,
#  567,
#  568,
#  569,
#  572,
#  576,
#  577,
#  578,
#  583,
#  584,
#  585,
#  587,
#  589,
#  590,
#  593,
#  595,
#  596,
#  603,
#  605,
#  607,
#  608,
#  609,
#  611,
#  613,
#  617,
#  618,
#  619,
#  620,
#  621,
#  622,
#  624,
#  626,
#  628,
#  631,
#  633,
#  635,
#  637,
#  638,
#  641,
#  645,
#  647,
#  648,
#  652,
#  654,
#  655,
#  657,
#  661,
#  663,
#  664,
#  665,
#  668,
#  671,
#  673,
#  675,
#  676,
#  677,
#  678,
#  680,
#  681,
#  688,
#  689,
#  691,
#  692,
#  693,
#  694,
#  695,
#  696,
#  698,
#  699,
#  700,
#  701,
#  702,
#  703,
#  712,
#  713,
#  714,
#  715,
#  717,
#  718,
#  719,
#  723,
#  724,
#  725,
#  726,
#  728,
#  729,
#  732,
#  733,
#  734,
#  735,
#  736,
#  737,
#  738,
#  740,
#  741,
#  747,
#  748,
#  752,
#  755,
#  756,
#  758,
#  762,
#  765,
#  766,
#  767,
#  769,
#  770,
#  771,
#  775,
#  783,
#  786,
#  787,
#  788,
#  789,
#  792,
#  796,
#  797,
#  798,
#  800,
#  802,
#  803,
#  804,
#  806,
#  807,
#  809,
#  810,
#  811,
#  812,
#  813,
#  814,
#  816,
#  817,
#  821,
#  825,
#  828,
#  831,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  840,
#  843,
#  844,
#  845,
#  849,
#  850,
#  851,
#  856,
#  857,
#  858,
#  863,
#  867,
#  869,
#  870,
#  871,
#  873,
#  874,
#  875,
#  876,
#  878,
#  880,
#  886,
#  887,
#  888,
#  889,
#  890,
#  892,
#  893,
#  894,
#  895,
#  900,
#  902,
#  904,
#  905,
#  906,
#  907,
#  909,
#  910,
#  911,
#  914,
#  915,
#  917,
#  919,
#  925,
#  926,
#  928,
#  929,
#  932,
#  934,
#  935,
#  936,
#  937,
#  938,
#  940,
#  943,
#  944,
#  945,
#  946,
#  947,
#  948,
#  949,
#  957,
#  961,
#  962,
#  964,
#  965,
#  967,
#  969,
#  972,
#  978,
#  980,
#  981,
#  984,
#  987,
#  988,
#  989,
#  990,
#  991,
#  992,
#  993,
#  994,
#  995,
#  997,
#  1000,
#  1003,
#  1007,
#  1008,
#  1010,
#  1012,
#  1013,
#  1014,
#  1015,
#  1016,
#  1021,
#  1022,
#  1024,
#  1025,
#  1027,
#  1028,
#  1029,
#  1030,
#  1032,
#  1034,
#  1037,
#  1043,
#  1046,
#  1047,
#  1048,
#  1049,
#  1050,
#  1051,
#  1052,
#  1053,
#  1055,
#  1057,
#  1063,
#  1067,
#  1068,
#  1072,
#  1077,
#  1083,
#  1084,
#  1085,
#  1086,
#  1087,
#  1090,
#  1094,
#  1098,
#  1099,
#  1101,
#  1103,
#  1104,
#  1105,
#  1107,
#  1110,
#  1112,
#  1114,
#  1115,
#  1116,
#  1118,
#  1119,
#  1121,
#  1122,
#  1124,
#  1128,
#  1129,
#  1130,
#  1131,
#  1133,
#  1137,
#  1138,
#  1140,
#  1141,
#  1143,
#  1144,
#  1145,
#  1146,
#  1147,
#  1150,
#  1151,
#  1153,
#  1154,
#  1156,
#  1158,
#  1161,
#  1162,
#  1164,
#  1166,
#  1167,
#  1168,
#  1170,
#  1171,
#  1172,
#  1174,
#  1175,
#  1177,
#  1178,
#  1179,
#  1183,
#  1187,
#  1190,
#  1195,
#  1197,
#  1198,
#  1200,
#  1201,
#  1202,
#  1204,
#  1206,
#  1207,
#  1209,
#  1212,
#  1213,
#  1214,
#  1215,
#  1217,
#  1218,
#  1221,
#  1222,
#  1224,
#  1225,
#  1226,
#  1228,
#  1232,
#  1233,
#  1234,
#  1236,
#  1239,
#  1242,
#  1243,
#  1244,
#  1246,
#  1247,
#  1249,
#  1250,
#  1252,
#  1256,
#  1258,
#  1260,
#  1261,
#  1263,
#  1264,
#  1265,
#  1266,
#  1267,
#  1269,
#  1270,
#  1276,
#  1278,
#  1280,
#  1281,
#  1282,
#  1284,
#  1290,
#  1291,
#  1292,
#  1293,
#  1295,
#  1297,
#  1301,
#  1303,
#  1307,
#  1308,
#  1311,
#  1312,
#  1313,
#  1315,
#  1318,
#  1319,
#  1321,
#  1322,
#  1323,
#  1325,
#  1330,
#  1336,
#  1337,
#  1338,
#  1339,
#  1340,
#  1344,
#  1347,
#  1350,
#  1351,
#  1354,
#  1355,
#  1356,
#  1357,
#  1358,
#  1359,
#  1360,
#  1362,
#  1364,
#  1365,
#  1366,
#  1373,
#  1374,
#  1376,
#  1377,
#  1380,
#  1381,
#  1384,
#  1389,
#  1390,
#  1393,
#  1394,
#  1395,
#  1396,
#  1398,
#  1399,
#  1403,
#  1404,
#  1407,
#  1410,
#  1411,
#  1412,
#  1415,
#  1416,
#  1418,
#  1420,
#  1421,
#  1422,
#  1425,
#  1427,
#  1429,
#  1432,
#  1433,
#  1434,
#  1436,
#  1438,
#  1440,
#  1447,
#  1448,
#  1449,
#  1450,
#  1454,
#  1455,
#  1457,
#  1459,
#  1462,
#  1463,
#  1464,
#  1467,
#  1468,
#  1471,
#  1473,
#  1474,
#  1478,
#  1480,
#  1481,
#  1482,
#  1484,
#  1486,
#  1489,
#  1491,
#  1493,
#  1494,
#  1498,
#  1501,
#  1503,
#  1504,
#  1507,
#  1508,
#  1510,
#  1511,
#  1515,
#  1517,
#  1518,
#  1519,
#  1521,
#  1523,
#  1524,
#  1525,
#  1526,
#  1527,
#  1530,
#  1531,
#  1533,
#  1534,
#  1535,
#  1538,
#  1539,
#  1542,
#  1543,
#  1546,
#  1547,
#  1551,
#  1553,
#  1556,
#  1557,
#  1562,
#  1565,
#  1567,
#  1568,
#  1570,
#  1572,
#  1573,
#  1579,
#  1584,
#  1585,
#  1587,
#  1591,
#  1592,
#  1593,
#  1594,
#  1595,
#  1598,
#  1599,
#  1600,
#  1603,
#  1604,
#  1605,
#  1606,
#  1607,
#  1608,
#  1609,
#  1614,
#  1619,
#  1620,
#  1622,
#  1623,
#  1624,
#  1625,
#  1626,
#  1627,
#  1628,
#  1630,
#  1633,
#  1635,
#  1638,
#  1641,
#  1642,
#  1643,
#  1645,
#  1646,
#  1647,
#  1649,
#  1653,
#  1659,
#  1660,
#  1661,
#  1663,
#  1664,
#  1665,
#  1667,
#  1668,
#  1669,
#  1670,
#  1671,
#  1673,
#  1674,
#  1676,
#  1677,
#  1678,
#  1685,
#  1687,
#  1689,
#  1690,
#  1691,
#  1693,
#  1694,
#  1695,
#  1696,
#  1697,
#  1698,
#  1700,
#  1703,
#  1705,
#  1707,
#  1708,
#  1711,
#  1712,
#  1717,
#  1718,
#  1719,
#  1720,
#  1722,
#  1723,
#  1724,
#  1725,
#  1727,
#  1728,
#  1729,
#  1731,
#  1737,
#  1738,
#  1741,
#  1743,
#  1745,
#  1747,
#  1750,
#  1751,
#  1756,
#  1757,
#  1758,
#  1761,
#  1762,
#  1763,
#  1764,
#  1765,
#  1766,
#  1767,
#  1768,
#  1771,
#  1774,
#  1775,
#  1776,
#  1779,
#  1782,
#  1784,
#  1788,
#  1791,
#  1792,
#  1794,
#  1796,
#  1798,
#  1802,
#  1807,
#  1808,
#  1810,
#  1812,
#  1814,
#  1817,
#  1818,
#  1819,
#  1823,
#  1824,
#  1826,
#  1830,
#  1831,
#  1832,
#  1833,
#  1834,
#  1836,
#  1838,
#  1841,
#  1845,
#  1849,
#  1850,
#  1851,
#  1852,
#  1855,
#  1856,
#  1861,
#  1862,
#  1863,
#  1866,
#  1867,
#  1872,
#  1878,
#  1879,
#  1880,
#  1881,
#  1882,
#  1884,
#  1886,
#  1888,
#  1889,
#  1892,
#  1893,
#  1895,
#  1897,
#  1904,
#  1905,
#  1906,
#  1908,
#  1910,
#  1911,
#  1922,
#  1923,
#  1925,
#  1926,
#  1931,
#  1932,
#  1933,
#  1937,
#  1938,
#  1939,
#  1940,
#  1943,
#  1948,
#  1950,
#  1951,
#  1953,
#  1954,
#  1955,
#  1957,
#  1961,
#  1962,
#  1963,
#  1964,
#  1965,
#  1966,
#  1969,
#  1973,
#  1974,
#  1977,
#  ...}

# %%
draw_graph(G,cut,pos)

# %%
print('cut-size: ',cut_size(G,cut))
# Out:
# cut-size:  155776

# %%
len(list(G.neighbors(3455)))
# Out:
# 15
