# %% [markdown]
# # Max-Cut Sample - Hybrid

# %%
import matplotlib.pyplot as plt
import networkx as nx
import dwave_networkx as dnx
import dimod

# %% [markdown]
# ### Helper Functions

# %%
def draw_graph(G,cut,pos):
    colors = [ 'g' if n in cut else 'r' for n in G.nodes() ]
    nx.draw(G,with_labels=True,alpha=0.6,node_size=100,node_color=colors,pos=pos)
    
def cut_size(G,cut):
    edges = 0
    for c in cut:
        for n in G.neighbors(c):
            if n not in cut:
                edges += 1
    return edges

# %% [markdown]
# ## Problem as Graph

# %%
# fixed graph
#G = nx.Graph()
#G.add_nodes_from([0,1,2,3,4])
#G.add_edges_from([(0,1),(1,2),(2,3),(3,0),(0,4),(2,4),(3,4),(1,4)])

# loaded sample graph
G = nx.read_edgelist('../sample_graphs/100-nodes-sample_hard.dat',nodetype=int)

#n = 4
#p = 0.3
#H = nx.gnp_random_graph(n, p)
pos = nx.spring_layout(G)

#nx.draw(G,with_labels=True,alpha=0.6,node_size=200,pos=pos)
draw_graph(G,{},pos)

# %%
print('Graph: ',len(G.nodes()), 'nodes, density: ',nx.density(G))
# Out:
# Graph:  100 nodes, density:  0.15171717171717172

# %% [markdown]
# ## Exact Solver

# %%
exactsolver = dimod.ExactSolver()

# %%
#import time

#ts_start = time.time()
#cut = dnx.maximum_cut(G, exactsolver)
#ts_stop = time.time()
#print(cut)
#print('elapsed time of exact solver (s): ',round(ts_stop - ts_start,2))

# %%
#draw_graph(G,cut,pos)

# %%
#print('cut-size: ',cut_size(G,cut))

# %% [markdown]
# ## Quantum Solver

# %%
from dwave.system import DWaveSampler, EmbeddingComposite

label = 'max-cut, n: ' + str(len(G.nodes())) + ', d: ' + str(round(nx.density(G),2)) + ' dwave'

sampler = EmbeddingComposite(DWaveSampler(solver={'topology__type': 'pegasus'}))
cut = dnx.maximum_cut(G, sampler,label=label,num_reads=4000)

# %%
cut
# Out:
# {1,
#  2,
#  6,
#  7,
#  8,
#  10,
#  13,
#  17,
#  24,
#  26,
#  27,
#  28,
#  29,
#  32,
#  33,
#  34,
#  35,
#  37,
#  38,
#  39,
#  40,
#  41,
#  42,
#  43,
#  44,
#  45,
#  51,
#  52,
#  58,
#  59,
#  61,
#  63,
#  64,
#  65,
#  68,
#  69,
#  71,
#  74,
#  75,
#  77,
#  78,
#  80,
#  81,
#  82,
#  83,
#  84,
#  85,
#  86,
#  88,
#  96,
#  98}

# %%
draw_graph(G,cut,pos)

# %%
print('cut-size: ',cut_size(G,cut))
# Out:
# cut-size:  499
